# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")
#Langugae=en
#type=core
#genre=web
#size=11mb sm=small

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7f0c2183db38>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7f0c2170fd08>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7f0c2170fd68>)]

# %%
doc=nlp(u"i am a student of computer science")

# %%
doc
# Out:
# i am a student of computer science

# %%
doc[0]
# Out:
# i

# %%
doc[3]
# Out:
# student

# %%
for token in doc:
  print(token.text)
# Out:
# i
# am
# a
# student
# of
# computer
# science

# %%
newDoc=nlp(u"This is senetence one. This is sentence2. This is senetence3. This is last sentence")

# %%
for sentence in newDoc.sents:
  print(sentence)
# Out:
# This is senetence one.
# This is sentence2.
# This is senetence3.
# This is last sentence

# %%
newDoc[1]
# Out:
# is

# %%
newDoc[5].is_sent_start
# Out:
# True

# %%
for token in newDoc:
  print(token.text,token.pos)
# Out:
# This 90
# is 87
# senetence 92
# one 93
# . 97
# This 90
# is 87
# sentence2 92
# . 97
# This 90
# is 87
# senetence3 92
# . 97
# This 90
# is 87
# last 84
# sentence 92

# %%
for token in newDoc:
  print(token.text,token.pos,token.pos_)
# Out:
# This 90 DET
# is 87 AUX
# senetence 92 NOUN
# one 93 NUM
# . 97 PUNCT
# This 90 DET
# is 87 AUX
# sentence2 92 NOUN
# . 97 PUNCT
# This 90 DET
# is 87 AUX
# senetence3 92 NOUN
# . 97 PUNCT
# This 90 DET
# is 87 AUX
# last 84 ADJ
# sentence 92 NOUN

# %%
for token in newDoc:
  print(token.text,token.pos,token.pos_,spacy.explain(token.pos_))
# Out:
# This 90 DET determiner
# is 87 AUX auxiliary
# senetence 92 NOUN noun
# one 93 NUM numeral
# . 97 PUNCT punctuation
# This 90 DET determiner
# is 87 AUX auxiliary
# sentence2 92 NOUN noun
# . 97 PUNCT punctuation
# This 90 DET determiner
# is 87 AUX auxiliary
# senetence3 92 NOUN noun
# . 97 PUNCT punctuation
# This 90 DET determiner
# is 87 AUX auxiliary
# last 84 ADJ adjective
# sentence 92 NOUN noun

# %%
for token in newDoc:
  print(token.text,token.pos,token.pos_,token.dep)
# Out:
# This 90 DET 429
# is 87 AUX 8206900633647566924
# senetence 92 NOUN 404
# one 93 NUM 12837356684637874264
# . 97 PUNCT 445
# This 90 DET 429
# is 87 AUX 8206900633647566924
# sentence2 92 NOUN 398
# . 97 PUNCT 445
# This 90 DET 429
# is 87 AUX 8206900633647566924
# senetence3 92 NOUN 398
# . 97 PUNCT 445
# This 90 DET 429
# is 87 AUX 8206900633647566924
# last 84 ADJ 402
# sentence 92 NOUN 404

# %%
for token in newDoc:
  print(token.text,token.pos,token.pos_,spacy.explain(token.pos_),token.dep,token.dep_,spacy.explain(token.dep_))
# Out:
# This 90 DET determiner 429 nsubj nominal subject
# is 87 AUX auxiliary 8206900633647566924 ROOT None
# senetence 92 NOUN noun 404 attr attribute
# one 93 NUM numeral 12837356684637874264 nummod numeric modifier
# . 97 PUNCT punctuation 445 punct punctuation
# This 90 DET determiner 429 nsubj nominal subject
# is 87 AUX auxiliary 8206900633647566924 ROOT None
# sentence2 92 NOUN noun 398 acomp adjectival complement
# . 97 PUNCT punctuation 445 punct punctuation
# This 90 DET determiner 429 nsubj nominal subject
# is 87 AUX auxiliary 8206900633647566924 ROOT None
# senetence3 92 NOUN noun 398 acomp adjectival complement
# . 97 PUNCT punctuation 445 punct punctuation
# This 90 DET determiner 429 nsubj nominal subject
# is 87 AUX auxiliary 8206900633647566924 ROOT None
# last 84 ADJ adjective 402 amod adjectival modifier
# sentence 92 NOUN noun 404 attr attribute

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer=PorterStemmer()

# %%
words=['run','running','runs','easily','talking','walks','gaming']

# %%
for word in words:
  print(word+"------->"+p_stemmer.stem(word))
# Out:
# run------->run
# running------->run
# runs------->run
# easily------->easili
# talking------->talk
# walks------->walk
# gaming------->game

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer=SnowballStemmer(language='english')

# %%
for word in words:
  print(word+"------->"+s_stemmer.stem(word))
# Out:
# run------->run
# running------->run
# runs------->run
# easily------->easili
# talking------->talk
# walks------->walk
# gaming------->game

# %%
doc_lemma=nlp(u'i am a runner in a race because i love to run since i ran this morning')

# %%
for token in doc_lemma:
  print(token.text,"\t",token.pos_,"\t",token.lemma,"\t",token.lemma_)
# Out:
# i 	 PRON 	 5097672513440128799 	 i
# am 	 AUX 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# i 	 PRON 	 5097672513440128799 	 i
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# i 	 PRON 	 5097672513440128799 	 i
# ran 	 VERB 	 12767647472892411841 	 run
# this 	 DET 	 1995909169258310477 	 this
# morning 	 NOUN 	 128801579471171342 	 morning

# %%
tokens=[token for token in doc_lemma]
tokens
# Out:
# [i,
#  am,
#  a,
#  runner,
#  in,
#  a,
#  race,
#  because,
#  i,
#  love,
#  to,
#  run,
#  since,
#  i,
#  ran,
#  this,
#  morning]
