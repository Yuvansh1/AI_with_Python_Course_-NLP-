# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
def show_Ents(doc):
  if doc.ents:
    for ent in doc.ents:
      print(ent.text+" - "+ent.label_+" - "+spacy.explain(ent.label_))
  else:    
    print("No Entity Found!!!")

# %%
doc=nlp(u"How are you?")

# %%
show_Ents(doc)
# Out:
# No Entity Found!!!

# %%
doc=nlp(u"May i go to New Delhi, to next December see Red Fort? Can you have 600 dollars for software tools?")

# %%
show_Ents(doc)
# Out:
# New Delhi - GPE - Countries, cities, states
# next December - DATE - Absolute or relative dates or periods
# Red Fort - FAC - Buildings, airports, highways, bridges, etc.
# 600 dollars - MONEY - Monetary values, including unit

# %%
ORG=doc.vocab.strings[u"ORG"]

# %%
ORG
# Out:
# 383

# %%
newdoc=nlp(u"She_tech is a very small company with respect to Google")

# %%
show_Ents(newdoc)
# Out:
# Google - ORG - Companies, agencies, institutions, etc.

# %%
from spacy.tokens import Span
newEnt=Span(newdoc,0,1,label=ORG)
newdoc.ents=list(newdoc.ents)+[newEnt]

# %%
show_Ents(newdoc)
# Out:
# She_tech - ORG - Companies, agencies, institutions, etc.
# Google - ORG - Companies, agencies, institutions, etc.

# %%
#Add Multiple Entity
from spacy.matcher import PhraseMatcher

# %%
matcher=PhraseMatcher(nlp.vocab)

# %%
article=nlp(u"Our company created a brand new vacuum*cleaner The new vacuum$cleaner is the best in show")

# %%
show_Ents(article)
# Out:
# No Entity Found!!!

# %%
phr_list=['vacuum*cleaner','vacuum$cleaner']

# %%
phr_patt=[nlp(text) for text in phr_list]
matcher.add('vacuumcleaner',None,*phr_patt)

# %%
found_matches=matcher(article)

# %%
found_matches
# Out:
# [(2062361704163117874, 6, 7), (2062361704163117874, 9, 10)]

# %%
PROD=doc.vocab.strings[u"PRODUCT"]

# %%
new_ents=[Span(doc,match[1],match[2],label=PROD)for match in found_matches]

# %%
article.ents=list(article.ents)+new_ents

# %%
show_Ents(article)
# Out:
# vacuum*cleaner - PRODUCT - Objects, vehicles, foods, etc. (not services)
# vacuum$cleaner - PRODUCT - Objects, vehicles, foods, etc. (not services)

# %%
#display in color
from spacy import displacy

# %%
displacy.render(doc,jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">May i go to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next December
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  see
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Red Fort
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ? Can you have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     600 dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for software tools?</div></span>

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
def String_to__url(url):
  res=requests.get(url)
  html=res.text
  soup=BeautifulSoup(html,'html5lib')
  for script in soup(["script","style","aside"]):
    script.extract()
  return "".join(re.split(r'[\n\t]+',soup.get_text()))

# %%
web_data_string=String_to__url("https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news")

# %%
article=nlp(web_data_string)

# %%
sentences=[x for x in article.sents]

# %%
sentences[2]
# Out:
# Credit...

# %%
from collections import Counter

# %%
#count all labels
labels=[x.label_ for x in article.ents]

# %%
Counter(labels)
# Out:
# Counter({'CARDINAL': 3,
#          'DATE': 23,
#          'GPE': 9,
#          'LOC': 1,
#          'NORP': 2,
#          'ORDINAL': 1,
#          'ORG': 37,
#          'PERSON': 77})

# %%
#most frequent token
items=[x.text for x in article.ents]

# %%
Counter(items).most_common(4)
# Out:
# [('Strzok', 29), ('F.B.I.', 18), ('Trump', 13), ('Russia', 6)]

# %%
displacy.render(nlp(str(sentences)),jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is Fired -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                       SectionsSEARCHSkip to contentSkip to site indexPoliticsToday’s PaperPolitics|F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,, Is Firedhttps://nyti.ms/2OtNre3AdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reading the main storyF.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FiredPeter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired., Credit...,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T.J. Kirkpatrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York TimesBy Adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Goldman and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael S. SchmidtAug.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior counterintelligence agent who disparaged President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in inflammatory text messages and helped oversee the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  email and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size:

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'’d', 'doing', 'becomes', 'five', 'how', "n't", 'mostly', 'besides', 'noone', 'other', 'sixty', '’m', 'while', 'mine', 'nobody', 'whose', 'eleven', 'about', 'alone', 'at', 'call', 'fifty', 'elsewhere', 'front', 'again', 'rather', 'one', 'up', 'using', 'latter', 'with', 'much', 'it', 'which', 'same', 'you', 'amount', 'from', 'well', 'third', 'whenever', 'beforehand', 'nine', 'empty', 'he', 'itself', 'are', 'became', 'here', 'top', 'she', 'will', 'very', 'of', 'out', 'toward', 'were', 'his', 'myself', 'first', 're', 'beyond', 'yourself', 'their', 'anyway', 'used', 'thereupon', 'hers', 'someone', 'next', 'though', 'seem', 'almost', 'off', 'around', 'side', 'name', 'its', 'get', 'more', 'forty', 'hereafter', 'therein', '‘m', '’ve', 'into', 'yours', "'re", 'once', 'have', 'if', 'was', 'been', 'quite', 'made', 'another', 'sometime', 'down', 'thru', 'various', 'for', 'therefore', 'amongst', 'our', 'by', 'really', 'ours', 'nevertheless', 'before', 'did', 'everything', 'had', 'namely', 'less', 'something', 'whom', 'both', 'yet', 'fifteen', 'beside', 'in', 'six', 'throughout', 'whereby', 'eight', 'wherever', 'ca', 'herein', 'three', 'bottom', 'do', 'moreover', 'sometimes', 'where', 'whither', 'former', 'go', 'meanwhile', 'afterwards', 'only', 'be', 'even', 'onto', 'since', "'m", 'move', 'either', 'none', 'there', 'thereby', 'whatever', 'such', 'although', '‘s', 'back', 'they', 'last', 'latterly', 'him', 'otherwise', 'over', 'then', 'behind', 'because', 'that', 'may', 'them', 'else', 'after', 'few', 'among', 'herself', 'being', 'when', 'above', 'always', 'serious', 'some', 'whence', 'whether', 'would', 'your', 'become', 'everywhere', 'towards', 'unless', 'please', 'n’t', 'or', 'themselves', 'seemed', 'via', 'still', 'these', 'twelve', 'under', 'whereas', 'hereby', 'also', 'enough', 'take', 'all', "'ve", 'each', 'now', 'most', 'not', 'ourselves', 'show', 'together', 'this', 'without', 'during', 'often', 'regarding', 'should', 'cannot', "'d", 'is', 'becoming', 'who', 'whoever', 'too', 'thence', 'perhaps', 'what', 'keep', '’re', 'further', 'whole', 'thus', 'within', 'see', 'a', 'nor', 'twenty', '‘d', 'me', 'himself', 'anything', 'many', 'just', 'could', 'full', 'i', 'make', 'never', 'nothing', 'along', 'indeed', 'nowhere', 'to', 'per', '‘ll', 'anyone', 'anyhow', 'already', 'can', 'but', 'her', 'least', 'hence', 'must', 'neither', 'somehow', 'than', 'whereupon', 'does', 'several', 'we', 'why', 'done', 'due', 'everyone', 'put', 'has', 'whereafter', 'am', 'as', 'those', 'yourselves', 'four', 'say', 'every', 'give', 'own', 'somewhere', 'two', 'us', 'below', 'so', "'ll", 'upon', 'against', 'ten', 'might', 'through', 'n‘t', 'any', '‘re', 'the', 'my', '‘ve', 'anywhere', 'until', '’s', 'except', '’ll', 'thereafter', "'s", 'an', 'on', 'no', 'seeming', 'across', 'however', 'seems', 'wherein', 'ever', 'hereupon', 'others', 'part', 'and', 'between', 'hundred', 'formerly'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['Rahul'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('pls')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
st_doc=nlp(u"Hello Mr. Shekhar, how are you, The weather is great, and city is very awesome the sky is pinkish blue. You should'nt eat pizza")

# %%
filter_data=[]
tokenize_doc=[]

# %%
for sw in st_doc:
  if not nlp.vocab[sw.text].is_stop:
    filter_data.append(sw)
  else:
    tokenize_doc.append(sw)
print(tokenize_doc)
print(filter_data)
# Out:
# [how, are, you, The, is, and, is, very, the, is, You]
# [Hello, Mr., Shekhar, ,, ,, weather, great, ,, city, awesome, sky, pinkish, blue, ., should'nt, eat, pizza]
